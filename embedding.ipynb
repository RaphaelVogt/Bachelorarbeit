# %%
import networkit as nk
import torch
from networkit import vizbridges

from embedding.graph import create_random_graph
from embedding.optimization import avg_distortion, create_uniform_data, distortion
from embedding.poincare import riemann_distance

# %%
data_points = 15

# %%
data_graph = create_random_graph(data_points, 1, 2, 1.5, 0.1)
vizbridges.widgetFromGraph(data_graph)
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'cose'}, cytoscape_style=[{'selector': 'node', 'css': {'background-c…

# %%
data_disk = create_uniform_data(data_points, -0.001, 0.001)
print(avg_distortion(data_disk, data_graph))
# Out:
# tensor(0.9987)

# %%
reals = torch.tensor([0.0, 0.0, 0.0]).reshape(3, 1)
imags = torch.tensor([0.1, 0.0, -0.1]).reshape(3, 1)
data_2 = torch.complex(reals, imags)
print(avg_distortion(data_2, data_graph))
print(distortion(0, 1, data_2, data_graph))
print(distance(data_2, 1, 2))
# Out:
# tensor(0.7659)
# tensor(0.7993)
# tensor(0.2007)
